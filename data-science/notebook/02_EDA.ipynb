# %%
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv("../data/processed/university_student_stress_clean.csv")
df.head()
# Out:
#    Unnamed: 0  Age  Gender  Study_Hours  Class_Attendance Tuition  \
# 0           0   24    Male          9.0              71.0      No
# 1           1   24  Female          8.0              43.0     Yes
# 2           2   21  Female          4.0              56.0     Yes
# 3           3   23  Female          4.0              46.0      No
# 4           4   20    Male          8.0              46.0      No
#
#    Exam_Frequency  Assignment_Load  Sleep_Hours  Caffeine_Intake_mg  \
# 0               7              4.0          6.0               200.0
# 1               6              8.0          5.0                 0.0
# 2               3              6.0          5.0               100.0
# 3               8              6.0          8.0                50.0
# 4               5              1.0          6.0               200.0
#
#   Physical_Exercise  Social_Media_Use  Screen_Time Family_Income_Level  \
# 0               Yes               6.0          9.0                 Low
# 1               Yes               6.0          8.0              Medium
# 2               Yes               7.0          9.0                 Low
# 3                No               5.0          6.0              Medium
# 4               Yes               0.0          7.0              Medium
#
#    Peer_Pressure  Family_Support  Anxiety_Level      University_Type  \
# 0            6.0             3.0            5.0  National University
# 1            3.0             7.0            8.0  National University
# 2            2.0             5.0            3.0   Private University
# 3            8.0             6.0            5.0   Private University
# 4            5.0             6.0            2.0  National University
#
#    Stress_Score Stress_Level
# 0            20       Medium
# 1            22         High
# 2            16       Medium
# 3            16       Medium
# 4             1          Low
